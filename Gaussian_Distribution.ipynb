# %% [markdown]
# # Standard distribution

# %% [markdown]
# Gaussian Distribution formula:
#
# $f(x,\mu,\sigma) = \frac{1}{\sigma\sqrt{2\pi}}e^\frac{-1}{2z^2}$

# %%
from IPython.

# %%
from IPython.display import Image
Image(url='http://upload.wikimedia.org/wikipedia/commons/thumb/2/25/The_Normal_Distribution.svg/725px-The_Normaal_Distribution.svg.png')
# Out:
# <img src="http://upload.wikimedia.org/wikipedia/commons/thumb/2/25/The_Normal_Distribution.svg/725px-The_Normal_Distribution.svg.png"/>

# %%
import numpy as np
import matplotlib.pyplot as plt
import math
from scipy.stats import norm

# %%
x = np.linspace(-1, 1, 100)
y = np.linspace(-1, 1, 100)

# %%
# Using scipy
plt.plot(x, norm.pdf(x, 0, .1))
plt.show()

# %%
def normpdf(x, mean, sd):
    var = float(sd)**2
    denom = (2*math.pi*var)**.5
    num = np.exp(-( x - mean)**2/(2*var))
    return num/denom

# %%
# using custom function
plt.plot(x, normpdf(x, 0, .1))
plt.show()
